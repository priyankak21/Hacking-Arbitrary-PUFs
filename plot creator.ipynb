# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
C = np.array([1000,100,10,8,4,1,0.1,0.01,0.001,0.0001,0.00001,0.000001])
train_time = np.array([35.21773348,27.71710874,27.13823916,18.00819482,16.2100363,13.1578421,11.62508976,11.18770594,16.34938146,13.8504024,14.09661444,16.90110534])
test_acc = np.array([0.9923,0.9931,0.9923,0.9922,0.9919,0.9906,0.9865,0.9559,0.8926,0.8379,0.8314,0.8312])
train_acc = np.array([1,0.999975,0.998875,0.99875,0.998325,0.996825,0.990875,0.96465,0.90125,0.8473,0.8392,0.83915])

# %%
plt.plot(C,test_acc,color = "b",marker = "*",label = "Testing Accuracy")
plt.plot(C,train_acc,color = "r",marker = "^",label = "Training Accuracy")
plt.xscale("log")
plt.grid()
plt.xlabel("C")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Logistic Regression")
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
plt.plot(C,train_time,color = "b",marker = "*",label = "Training Time")
plt.xscale("log")
plt.grid()
plt.xlabel("C")
plt.ylabel("Time in seconds")
plt.legend()
plt.title("Logistic Regression")
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
tol = np.array([10,1,0.1,0.01,0.001,0.0001,0.00001])
train_time = np.array([12.2479888,12.4486464,24.27954388,23.73711124,20.5120574,25.71676266,21.59570308])
test_acc = np.array([0.5054,0.8279,0.9689,0.9915,0.9921,0.9922,0.9922])
train_acc = np.array([0.49865,0.8384,0.97792,0.99745,0.998675,0.99875,0.99875])
plt.plot(tol,test_acc,color = "b",marker = "*",label = "Testing Accuracy")
plt.plot(tol,train_acc,color = "r",marker = "^",label = "Training Accuracy")
plt.xscale("log")
plt.grid()
plt.xlabel("tol")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Logistic Regression")
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
plt.plot(tol,train_time,color = "b",marker = "*",label = "Training time")

plt.xscale("log")
plt.grid()
plt.xlabel("tol")
plt.ylabel("Time in seconds")
plt.legend()
plt.title("Logistic Regression")
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
C = np.array([100,10,1,0.1,0.01,0.001,0.0001,])
train_time = np.array([37.39457844,13.6516622,10.93814084,10.82038854,10.76110498,10.51001234,11.32988648,])
test_acc = np.array([0.9921,0.9929,0.9919,0.9899,0.9865,0.9598,0.8805,])
train_acc = np.array([1,0.99995,0.998625,0.99595,0.990875,0.96665,0.888625,])
plt.plot(C,test_acc,color = "b",marker = "*",label = "Testing Accuracy")
plt.plot(C,train_acc,color = "r",marker = "^",label = "Training Accuracy")
plt.xscale("log")
plt.grid()
plt.xlabel("C")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Linear SVM")
# Out:
# Text(0.5, 1.0, 'Linear SVM')

# %%
C = np.array([100,10,1,0.1,0.01,0.001,0.0001,])
train_time = np.array([37.39457844,13.6516622,10.93814084,10.82038854,10.76110498,10.51001234,11.32988648,])
test_acc = np.array([0.9921,0.9929,0.9919,0.9899,0.9865,0.9598,0.8805,])
train_acc = np.array([1,0.99995,0.998625,0.99595,0.990875,0.96665,0.888625,])

plt.plot(C,train_time,color = "b",marker = "^",label = "Training Time")
plt.xscale("log")
plt.grid()
plt.xlabel("C")
plt.ylabel("Time in seconds")
plt.legend()
plt.title("Linear SVM")
# Out:
# Text(0.5, 1.0, 'Linear SVM')

# %%
tol = np.array([100,10,1,0.1,0.01,0.001,0.0001,0.00001,0.000001,])
train_time = np.array([9.74484114,8.96286812,10.04022706,10.1661239,11.35942096,11.54725316,11.52054412,20.47215006,12.08167772])
test_acc = np.array([0.5054,0.5054,0.8279,0.9787,0.9922,0.9934,0.9929,0.9919,0.993,])
train_acc = np.array([0.49865,0.49865,0.8384,0.9841,0.999025,0.999875,0.99995,0.998625,0.99995,])
plt.plot(tol,test_acc,color = "b",marker = "*",label = "Testing Accuracy")
plt.plot(tol,train_acc,color = "r",marker = "^",label = "Training Accuracy")
plt.xscale("log")
plt.grid()
plt.xlabel("tol")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Linear SVM")
# Out:
# Text(0.5, 1.0, 'Linear SVM')

# %%
plt.plot(tol,train_time,color = "b",marker = "^",label = "Training Time")
plt.xscale("log")
plt.grid()
plt.xlabel("tol")
plt.ylabel("Time in seconds")
plt.legend()
plt.title("Linear SVM")
# Out:
# Text(0.5, 1.0, 'Linear SVM')
